# %% [markdown]
# ### Conhecendo a Request

# %% [markdown]
# Primeira Requisição
# * https://requests.readthedocs.io/en/latest/user/quickstart/

# %%
import requests

# %%
# requisição para o servidor com o metódo GET (envio de dados especificos pelo servidor ao cliente)
r = requests.get('https://api.github.com/events')

# %% [markdown]
# #### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.headers['Content-Type']
# Out:
# 'application/json; charset=utf-8'

# %%
# tras todo o json em forma de string
r.text
# Out:
# '[{"id":"40405649047","type":"PushEvent","actor":{"id":165615328,"login":"simon-m-dignite","display_login":"simon-m-dignite","gravatar_id":"","url":"https://api.github.com/users/simon-m-dignite","avatar_url":"https://avatars.githubusercontent.com/u/165615328?"},"repo":{"id":795729453,"name":"dignitestudios-dev/DS-website","url":"https://api.github.com/repos/dignitestudios-dev/DS-website"},"payload":{"repository_id":795729453,"push_id":19451025499,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"7922096d21fdaee3cc6db597c60e647d3858c727","before":"1d5dda6468007d8c16cc5b92255e74b746faa975","commits":[{"sha":"7922096d21fdaee3cc6db597c60e647d3858c727","author":{"email":"shoaib.muhammad@launchbox.pk","name":"simon-m-dignite"},"message":"home page changes and web app dev service page donw","distinct":true,"url":"https://api.github.com/repos/dignitestudios-dev/DS-website/commits/7922096d21fdaee3cc6db597c60e647d3858c727"}]},"public":true,"created_at":"2024-07-23T23:26:11Z"},{"id":"40405649042","type":"PushEvent","actor":{"id":99732548,"login":"Alexey-Gorulev-kernelics","display_login":"Alexey-Gorulev-kernelics","gravatar_id":"","url":"https://api.github.com/users/Alexey-Gorulev-kernelics","avatar_url":"https://avatars.githubusercontent.com/u/99732548?"},"repo":{"id":594025267,"name":"magicwave-io/go-ipfs","url":"https://api.github.com/repos/magicwave-io/go-ipfs"},"payload":{"repository_id":594025267,"push_id":19451025495,"size":1,"distinct_size":1,"ref":"refs/heads/feat/stabilize-dht-systemd","head":"4e2fba611af6224cc0c00c1dc708f3f700d7ff49","before":"d1d07049ce969f7f2b21852e33d40bd20dcc7ec8","commits":[{"sha":"4e2fba611af6224cc0c00c1dc708f3f700d7ff49","author":{"email":"a.gorulev@kernelics.com","name":"a.gorulev"},"message":"magicwave.io","distinct":true,"url":"https://api.github.com/repos/magicwave-io/go-ipfs/commits/4e2fba611af6224cc0c00c1dc708f3f700d7ff49"}]},"public":true,"created_at":"2024-07-23T23:26:11Z","org":{"id":123494304,"login":"magicwave-io","gravatar_id":"","url":"https://api.github.com/orgs/magicwave-io","avatar_url":"https://avatars.githubusercontent.com/u/123494304?"}},{"id":"40405649041","type":"PushEvent","actor":{"id":95522935,"login":"haitaoo1","display_login":"haitaoo1","gravatar_id":"","url":"https://api.github.com/users/haitaoo1","avatar_url":"https://avatars.githubusercontent.com/u/95522935?"},"repo":{"id":823401350,"name":"haitaoo1/Book-Comunnity","url":"https://api.github.com/repos/haitaoo1/Book-Comunnity"},"payload":{"repository_id":823401350,"push_id":19451025501,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"ad4aa74b81f63ae04df2c4a4918fe1d95385d551","before":"f69e5802ac29d6fac4b564ed4203e728ececc037","commits":[{"sha":"ad4aa74b81f63ae04df2c4a4918fe1d95385d551","author":{"email":"haitaowu14@gmail.com","name":"Haitao Wu"},"message":"UI setting","distinct":true,"url":"https://api.github.com/repos/haitaoo1/Book-Comunnity/commits/ad4aa74b81f63ae04df2c4a4918fe1d95385d551"}]},"public":true,"created_at":"2024-07-23T23:26:11Z"},{"id":"40405649028","type":"PushEvent","actor":{"id":150383396,"login":"john-thomas-gray","display_login":"john-thomas-gray","gravatar_id":"","url":"https://api.github.com/users/john-thomas-gray","avatar_url":"https://avatars.githubusercontent.com/u/150383396?"},"repo":{"id":807348423,"name":"john-thomas-gray/Portfolio","url":"https://api.github.com/repos/john-thomas-gray/Portfolio"},"payload":{"repository_id":807348423,"push_id":19451025492,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"9a35ca0f64a91c3dd3f1a4a8c8b1ddc4f8b4248b","before":"32ac8fc2cbffbea21de2a0ad609d203ba576d488","commits":[{"sha":"9a35ca0f64a91c3dd3f1a4a8c8b1ddc4f8b4248b","author":{"email":"john.thom.gray@gmail.com","name":"John"},"message":"gradient color swap","distinct":true,"url":"https://api.github.com/repos/john-thomas-gray/Portfolio/commits/9a35ca0f64a91c3dd3f1a4a8c8b1ddc4f8b4248b"}]},"public":true,"created_at":"2024-07-23T23:26:11Z"},{"id":"40405649033","type":"IssuesEvent","actor ...

# %%
r.json()
# Out:
# [{'id': '40405649047',
#   'type': 'PushEvent',
#   'actor': {'id': 165615328,
#    'login': 'simon-m-dignite',
#    'display_login': 'simon-m-dignite',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simon-m-dignite',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/165615328?'},
#   'repo': {'id': 795729453,
#    'name': 'dignitestudios-dev/DS-website',
#    'url': 'https://api.github.com/repos/dignitestudios-dev/DS-website'},
#   'payload': {'repository_id': 795729453,
#    'push_id': 19451025499,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7922096d21fdaee3cc6db597c60e647d3858c727',
#    'before': '1d5dda6468007d8c16cc5b92255e74b746faa975',
#    'commits': [{'sha': '7922096d21fdaee3cc6db597c60e647d3858c727',
#      'author': {'email': 'shoaib.muhammad@launchbox.pk',
#       'name': 'simon-m-dignite'},
#      'message': 'home page changes and web app dev service page donw',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/dignitestudios-dev/DS-website/commits/7922096d21fdaee3cc6db597c60e647d3858c727'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405649042',
#   'type': 'PushEvent',
#   'actor': {'id': 99732548,
#    'login': 'Alexey-Gorulev-kernelics',
#    'display_login': 'Alexey-Gorulev-kernelics',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alexey-Gorulev-kernelics',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99732548?'},
#   'repo': {'id': 594025267,
#    'name': 'magicwave-io/go-ipfs',
#    'url': 'https://api.github.com/repos/magicwave-io/go-ipfs'},
#   'payload': {'repository_id': 594025267,
#    'push_id': 19451025495,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feat/stabilize-dht-systemd',
#    'head': '4e2fba611af6224cc0c00c1dc708f3f700d7ff49',
#    'before': 'd1d07049ce969f7f2b21852e33d40bd20dcc7ec8',
#    'commits': [{'sha': '4e2fba611af6224cc0c00c1dc708f3f700d7ff49',
#      'author': {'email': 'a.gorulev@kernelics.com', 'name': 'a.gorulev'},
#      'message': 'magicwave.io',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/magicwave-io/go-ipfs/commits/4e2fba611af6224cc0c00c1dc708f3f700d7ff49'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z',
#   'org': {'id': 123494304,
#    'login': 'magicwave-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/magicwave-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123494304?'}},
#  {'id': '40405649041',
#   'type': 'PushEvent',
#   'actor': {'id': 95522935,
#    'login': 'haitaoo1',
#    'display_login': 'haitaoo1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haitaoo1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95522935?'},
#   'repo': {'id': 823401350,
#    'name': 'haitaoo1/Book-Comunnity',
#    'url': 'https://api.github.com/repos/haitaoo1/Book-Comunnity'},
#   'payload': {'repository_id': 823401350,
#    'push_id': 19451025501,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ad4aa74b81f63ae04df2c4a4918fe1d95385d551',
#    'before': 'f69e5802ac29d6fac4b564ed4203e728ececc037',
#    'commits': [{'sha': 'ad4aa74b81f63ae04df2c4a4918fe1d95385d551',
#      'author': {'email': 'haitaowu14@gmail.com', 'name': 'Haitao Wu'},
#      'message': 'UI setting',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/haitaoo1/Book-Comunnity/commits/ad4aa74b81f63ae04df2c4a4918fe1d95385d551'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405649028',
#   'type': 'PushEvent',
#   'actor': {'id': 150383396,
#    'login': 'john-thomas-gray',
#    'display_login': 'john-thomas-gray',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/john-thomas-gray',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/150383396?'},
#   'repo': {'id': 807348423,
#    'name': 'john-thomas-gray/Portfolio',
#    'url': 'https://api.github.com/repos/john-thomas-gray/Portfolio'},
#   'payload': {'repository_id': 807348423,
#    'push_id': 19451025492,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9a35ca0f64a91c3dd3f1a4a8c8b1ddc4f8b4248b',
#    'before': '32ac8fc2cbffbea21de2a0ad609d203ba576d488',
#    'commits': [{'sha': '9a35ca0f64a91c3dd3f1a4a8c8b1ddc4f8b4248b',
#      'author': {'email': 'john.thom.gray@gmail.com', 'name': 'John'},
#      'message': 'gradient color swap',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/john-thomas-gray/Portfolio/commits/9a35ca0f64a91c3dd3f1a4a8c8b1ddc4f8b4248b'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405649033',
#   'type': 'IssuesEvent',
#   'actor': {'id': 100868164,
#    'login': 'staging-whitesource-for-github-com[bot]',
#    'display_login': 'staging-whitesource-for-github-com',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/staging-whitesource-for-github-com[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/100868164?'},
#   'repo': {'id': 832880397,
#    'name': 'ghc-automation-staging-parallel-11-p3/11653742_343',
#    'url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343/issues/15',
#     'repository_url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343',
#     'labels_url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343/issues/15/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343/issues/15/comments',
#     'events_url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343/issues/15/events',
#     'html_url': 'https://github.com/ghc-automation-staging-parallel-11-p3/11653742_343/issues/15',
#     'id': 2426271838,
#     'node_id': 'I_kwDOMaS_Dc6Qnfhe',
#     'number': 15,
#     'title': 'CVE-2017-16082 (Critical) detected in pg-5.1.0.tgz - autoclosed',
#     'user': {'login': 'staging-whitesource-for-github-com[bot]',
#      'id': 100868164,
#      'node_id': 'BOT_kgDOBgMgRA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1539627?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D',
#      'html_url': 'https://github.com/apps/staging-whitesource-for-github-com',
#      'followers_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/staging-whitesource-for-github-com%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 7242440970,
#       'node_id': 'LA_kwDOMaS_Dc8AAAABr67hCg',
#       'url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343/labels/Mend:%20dependency%20security%20vulnerability',
#       'name': 'Mend: dependency security vulnerability',
#       'color': 'd1260f',
#       'default': False,
#       'description': 'Security vulnerability detected by WhiteSource'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2024-07-23T23:20:20Z',
#     'updated_at': '2024-07-23T23:26:11Z',
#     'closed_at': '2024-07-23T23:26:10Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': '## CVE-2017-16082 - Critical Severity Vulnerability\n<details><summary><img src=\'https://whitesource-resources.whitesourcesoftware.com/vulnerability_details.png\' width=19 height=20> Vulnerable Library - <b>pg-5.1.0.tgz</b></p></summary>\n\n<p>PostgreSQL client - pure javascript & libpq with the same API</p>\n<p>Library home page: <a href="https://registry.npmjs.org/pg/-/pg-5.1.0.tgz">https://registry.npmjs.org/pg/-/pg-5.1.0.tgz</a></p>\n<p>Path to dependency file: /package.json</p>\n<p>Path to vulnerable library: /node_modules/pg/package.json</p>\n<p>\n\nDependency Hierarchy:\n  - pg-promise-4.8.1.tgz (Root Library)\n    - :x: **pg-5.1.0.tgz** (Vulnerable Library)\n<p>Found in HEAD commit: <a href="https://github.com/ghc-automation-staging-parallel-11-p3/11653742_343/commit/3ee9074d760e0e36ba905721383e4eaaf2016438">3ee9074d760e0e36ba905721383e4eaaf2016438</a></p>\n<p>Found in base branch: <b>main</b></p>\n</p>\n</details>\n<p></p>\n<details><summary><img src=\'https://whitesource-resources.whitesourcesoftware.com/critical_vul.png?\' width=19 height=20> Vulnerability Details</summary>\n<p>  \n  \nA remote code execution vulnerability was found within the pg module when the remote database or query specifies a specially crafted column name. There are 2 likely scenarios in which one would likely be vulnerable. 1) Executing unsafe, user-supplied sql which contains a malicious column name. 2) Connecting to an untrusted database and executing a query which returns results where any of the column names are malicious.\n\n<p>Publish Date: 2018-04-26\n<p>URL: <a href=https://www.mend.io/vulnerability-database/CVE-2017-16082>CVE-2017-16082</a></p>\n</p>\n</details>\n<p></p>\n<details><summary><img src=\'https://whitesource-resources.whitesourcesoftware.com/cvss3.png\' width=19 height=20> CVSS 3 Score Details (<b>9.8</b>)</summary>\n<p>\n\nBase Score Metrics:\n- Exploitability Metrics:\n  - Attack Vector: Network\n  - Attack Complexity: Low\n  - Privileges Required: None\n  - User Interaction: None\n  - Scope: Unchanged\n- Impact Metrics:\n  - Confidentiality Impact: High\n  - Integrity Impact: High\n  - Availability Impact: High\n</p>\nFor more information on CVSS3 Scores, click <a href="https://www.first.org/cvss/calculator/3.0">here</a>.\n</p>\n</details>\n<p></p>\n<details><summary><img src=\'https://whitesource-resources.whitesourcesoftware.com/suggested_fix.png\' width=19 height=20> Suggested Fix</summary>\n<p>\n\n<p>Type: Upgrade version</p>\n<p>Origin: <a href="https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2017-16082">https://cve.mitre.org/cgi-bin/cvename.cgi?name=CVE-2017-16082</a></p>\n<p>Release Date: 2018-04-26</p>\n<p>Fix Resolution (pg): 6.0.5</p>\n<p>Direct dependency fix Resolution (pg-promise): 6.0.0</p>\n\n</p>\n</details>\n<p></p>\n\n***\n:rescue_worker_helmet: Automatic Remediation will be attempted for this issue.',
#     'reactions': {'url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343/issues/15/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ghc-automation-staging-parallel-11-p3/11653742_343/issues/15/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'}},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z',
#   'org': {'id': 168727045,
#    'login': 'ghc-automation-staging-parallel-11-p3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ghc-automation-staging-parallel-11-p3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/168727045?'}},
#  {'id': '40405649021',
#   'type': 'PushEvent',
#   'actor': {'id': 53265588,
#    'login': 'LuoShaoyin',
#    'display_login': 'LuoShaoyin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LuoShaoyin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53265588?'},
#   'repo': {'id': 823446782,
#    'name': 'LuoShaoyin/ip',
#    'url': 'https://api.github.com/repos/LuoShaoyin/ip'},
#   'payload': {'repository_id': 823446782,
#    'push_id': 19451025477,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'da910a5120f64782b35081ba444951629343dffb',
#    'before': 'd81238d83162fdd3438165127424424b61a304de',
#    'commits': [{'sha': 'da910a5120f64782b35081ba444951629343dffb',
#      'author': {'email': 'luoshaoyin641@outlook.com', 'name': 'LuoShaoyinn'},
#      'message': 'Wed Jul 24 07:26:07 AM CST 2024',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/LuoShaoyin/ip/commits/da910a5120f64782b35081ba444951629343dffb'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405649015',
#   'type': 'PushEvent',
#   'actor': {'id': 48321566,
#    'login': 'twoneis',
#    'display_login': 'twoneis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoneis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48321566?'},
#   'repo': {'id': 717771357,
#    'name': 'twoneis/nix-config',
#    'url': 'https://api.github.com/repos/twoneis/nix-config'},
#   'payload': {'repository_id': 717771357,
#    'push_id': 19451025482,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fe981d058f46aa6e6e4b26e091dd656b0ea84c8a',
#    'before': '38949ee1b7e22ec676e5eecdeb71f49c2d561645',
#    'commits': [{'sha': 'fe981d058f46aa6e6e4b26e091dd656b0ea84c8a',
#      'author': {'email': 'sanjay29@sapura.de', 'name': 'twoneis'},
#      'message': 'network manager',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/twoneis/nix-config/commits/fe981d058f46aa6e6e4b26e091dd656b0ea84c8a'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405649013',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 783728372,
#    'name': 'mehulcode12/mehulcode12',
#    'url': 'https://api.github.com/repos/mehulcode12/mehulcode12'},
#   'payload': {'repository_id': 783728372,
#    'push_id': 19451025479,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/output',
#    'head': '48e28c28670fbdcbb9f37d42faa700b0e5b0ef10',
#    'before': 'b9f3e8533a707165984e47e855ac353a00b8e852',
#    'commits': [{'sha': '48e28c28670fbdcbb9f37d42faa700b0e5b0ef10',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Deploy to GitHub pages',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mehulcode12/mehulcode12/commits/48e28c28670fbdcbb9f37d42faa700b0e5b0ef10'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405649006',
#   'type': 'PushEvent',
#   'actor': {'id': 8112632,
#    'login': 'cBournhonesque',
#    'display_login': 'cBournhonesque',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cBournhonesque',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8112632?'},
#   'repo': {'id': 831458688,
#    'name': 'cBournhonesque/jam5',
#    'url': 'https://api.github.com/repos/cBournhonesque/jam5'},
#   'payload': {'repository_id': 831458688,
#    'push_id': 19451025462,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '05d77f0e8c8536eb48b8a4129f6936ffd9461298',
#    'before': '4589ca2b2b72b94de95b0bca8f2d09ed2260f41a',
#    'commits': [{'sha': 'd233cf231e482200ca0d5f1b95115418aa21fb84',
#      'author': {'email': 'charlesbour@gmail.com', 'name': 'cBournhonesque'},
#      'message': 'add score',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/cBournhonesque/jam5/commits/d233cf231e482200ca0d5f1b95115418aa21fb84'},
#     {'sha': '05d77f0e8c8536eb48b8a4129f6936ffd9461298',
#      'author': {'email': 'charlesbour@gmail.com', 'name': 'Periwink'},
#      'message': 'Merge pull request #23 from cBournhonesque/cb/update-score\n\nadd score',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cBournhonesque/jam5/commits/05d77f0e8c8536eb48b8a4129f6936ffd9461298'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405649001',
#   'type': 'PushEvent',
#   'actor': {'id': 450800,
#    'login': 'sthagen',
#    'display_login': 'sthagen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sthagen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/450800?'},
#   'repo': {'id': 494678554,
#    'name': 'sthagen/PyO3-maturin',
#    'url': 'https://api.github.com/repos/sthagen/PyO3-maturin'},
#   'payload': {'repository_id': 494678554,
#    'push_id': 19451025468,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/main',
#    'head': '46cce0312f0379b6dfe16040b0c8bee4b4aae1ba',
#    'before': 'fdad7bf25e7e1a6e38a40306e14d2a3fc6c84d31',
#    'commits': [{'sha': '223293b0b29ed1abed1240e022e69b5015a5bba4',
#      'author': {'email': 'messense@icloud.com', 'name': 'messense'},
#      'message': 'Upgrade pyproject-toml to 0.11.0 (#2155)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sthagen/PyO3-maturin/commits/223293b0b29ed1abed1240e022e69b5015a5bba4'},
#     {'sha': '46cce0312f0379b6dfe16040b0c8bee4b4aae1ba',
#      'author': {'email': 'ich@tinowagner.com', 'name': 'Tino Wagner'},
#      'message': 'Fix platform tags when cross-compiling universal2 (#2153)\n\nWhen cross-compiling for `universal2-apple-darwin`, the platform tags of\r\nthe resulting wheel were not properly derived. This is because with\r\nforcing `target_triple` to `None` as before, it was not detected that we\r\nare in fact cross-compiling for a different target and thus the wheels\r\nwere wrongly tagged for the host platform.\r\n\r\nTo make the inference work, set `target_triple` to a valid triple\r\ninstead.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sthagen/PyO3-maturin/commits/46cce0312f0379b6dfe16040b0c8bee4b4aae1ba'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405649011',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 1423735,
#    'login': 'tlvaldepena',
#    'display_login': 'tlvaldepena',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tlvaldepena',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1423735?'},
#   'repo': {'id': 832880166,
#    'name': 'tlvaldepena/skills-github-pages',
#    'url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages'},
#   'payload': {'action': 'opened',
#    'number': 1,
#    'pull_request': {'url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls/1',
#     'id': 1984297512,
#     'node_id': 'PR_kwDOMaS-Js52Rfoo',
#     'html_url': 'https://github.com/tlvaldepena/skills-github-pages/pull/1',
#     'diff_url': 'https://github.com/tlvaldepena/skills-github-pages/pull/1.diff',
#     'patch_url': 'https://github.com/tlvaldepena/skills-github-pages/pull/1.patch',
#     'issue_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues/1',
#     'number': 1,
#     'state': 'open',
#     'locked': False,
#     'title': 'My pages',
#     'user': {'login': 'tlvaldepena',
#      'id': 1423735,
#      'node_id': 'MDQ6VXNlcjE0MjM3MzU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1423735?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tlvaldepena',
#      'html_url': 'https://github.com/tlvaldepena',
#      'followers_url': 'https://api.github.com/users/tlvaldepena/followers',
#      'following_url': 'https://api.github.com/users/tlvaldepena/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tlvaldepena/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tlvaldepena/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tlvaldepena/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tlvaldepena/orgs',
#      'repos_url': 'https://api.github.com/users/tlvaldepena/repos',
#      'events_url': 'https://api.github.com/users/tlvaldepena/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tlvaldepena/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2024-07-23T23:26:10Z',
#     'updated_at': '2024-07-23T23:26:10Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls/1/commits',
#     'review_comments_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls/1/comments',
#     'review_comment_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues/1/comments',
#     'statuses_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/statuses/77c68df05877388ba4fd7c66dc1887f8d8952faa',
#     'head': {'label': 'tlvaldepena:my-pages',
#      'ref': 'my-pages',
#      'sha': '77c68df05877388ba4fd7c66dc1887f8d8952faa',
#      'user': {'login': 'tlvaldepena',
#       'id': 1423735,
#       'node_id': 'MDQ6VXNlcjE0MjM3MzU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1423735?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tlvaldepena',
#       'html_url': 'https://github.com/tlvaldepena',
#       'followers_url': 'https://api.github.com/users/tlvaldepena/followers',
#       'following_url': 'https://api.github.com/users/tlvaldepena/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tlvaldepena/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tlvaldepena/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tlvaldepena/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tlvaldepena/orgs',
#       'repos_url': 'https://api.github.com/users/tlvaldepena/repos',
#       'events_url': 'https://api.github.com/users/tlvaldepena/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tlvaldepena/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 832880166,
#       'node_id': 'R_kgDOMaS-Jg',
#       'name': 'skills-github-pages',
#       'full_name': 'tlvaldepena/skills-github-pages',
#       'private': False,
#       'owner': {'login': 'tlvaldepena',
#        'id': 1423735,
#        'node_id': 'MDQ6VXNlcjE0MjM3MzU=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1423735?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tlvaldepena',
#        'html_url': 'https://github.com/tlvaldepena',
#        'followers_url': 'https://api.github.com/users/tlvaldepena/followers',
#        'following_url': 'https://api.github.com/users/tlvaldepena/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tlvaldepena/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tlvaldepena/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tlvaldepena/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tlvaldepena/orgs',
#        'repos_url': 'https://api.github.com/users/tlvaldepena/repos',
#        'events_url': 'https://api.github.com/users/tlvaldepena/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tlvaldepena/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tlvaldepena/skills-github-pages',
#       'description': 'My clone repository',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages',
#       'forks_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/forks',
#       'keys_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/teams',
#       'hooks_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/events',
#       'assignees_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/tags',
#       'blobs_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/languages',
#       'stargazers_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/subscription',
#       'commits_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/merges',
#       'archive_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/downloads',
#       'issues_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/deployments',
#       'created_at': '2024-07-23T23:13:34Z',
#       'updated_at': '2024-07-23T23:24:44Z',
#       'pushed_at': '2024-07-23T23:26:10Z',
#       'git_url': 'git://github.com/tlvaldepena/skills-github-pages.git',
#       'ssh_url': 'git@github.com:tlvaldepena/skills-github-pages.git',
#       'clone_url': 'https://github.com/tlvaldepena/skills-github-pages.git',
#       'svn_url': 'https://github.com/tlvaldepena/skills-github-pages',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'tlvaldepena:main',
#      'ref': 'main',
#      'sha': '0bad22e7de2badad57aa948ee862b9c467e56d07',
#      'user': {'login': 'tlvaldepena',
#       'id': 1423735,
#       'node_id': 'MDQ6VXNlcjE0MjM3MzU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1423735?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/tlvaldepena',
#       'html_url': 'https://github.com/tlvaldepena',
#       'followers_url': 'https://api.github.com/users/tlvaldepena/followers',
#       'following_url': 'https://api.github.com/users/tlvaldepena/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/tlvaldepena/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/tlvaldepena/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/tlvaldepena/subscriptions',
#       'organizations_url': 'https://api.github.com/users/tlvaldepena/orgs',
#       'repos_url': 'https://api.github.com/users/tlvaldepena/repos',
#       'events_url': 'https://api.github.com/users/tlvaldepena/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/tlvaldepena/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 832880166,
#       'node_id': 'R_kgDOMaS-Jg',
#       'name': 'skills-github-pages',
#       'full_name': 'tlvaldepena/skills-github-pages',
#       'private': False,
#       'owner': {'login': 'tlvaldepena',
#        'id': 1423735,
#        'node_id': 'MDQ6VXNlcjE0MjM3MzU=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/1423735?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/tlvaldepena',
#        'html_url': 'https://github.com/tlvaldepena',
#        'followers_url': 'https://api.github.com/users/tlvaldepena/followers',
#        'following_url': 'https://api.github.com/users/tlvaldepena/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/tlvaldepena/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/tlvaldepena/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/tlvaldepena/subscriptions',
#        'organizations_url': 'https://api.github.com/users/tlvaldepena/orgs',
#        'repos_url': 'https://api.github.com/users/tlvaldepena/repos',
#        'events_url': 'https://api.github.com/users/tlvaldepena/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/tlvaldepena/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/tlvaldepena/skills-github-pages',
#       'description': 'My clone repository',
#       'fork': False,
#       'url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages',
#       'forks_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/forks',
#       'keys_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/teams',
#       'hooks_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/hooks',
#       'issue_events_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/events',
#       'assignees_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/tags',
#       'blobs_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/languages',
#       'stargazers_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/stargazers',
#       'contributors_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/contributors',
#       'subscribers_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/subscribers',
#       'subscription_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/subscription',
#       'commits_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/merges',
#       'archive_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/downloads',
#       'issues_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/deployments',
#       'created_at': '2024-07-23T23:13:34Z',
#       'updated_at': '2024-07-23T23:24:44Z',
#       'pushed_at': '2024-07-23T23:26:10Z',
#       'git_url': 'git://github.com/tlvaldepena/skills-github-pages.git',
#       'ssh_url': 'git@github.com:tlvaldepena/skills-github-pages.git',
#       'clone_url': 'https://github.com/tlvaldepena/skills-github-pages.git',
#       'svn_url': 'https://github.com/tlvaldepena/skills-github-pages',
#       'homepage': None,
#       'size': 0,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': None,
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls/1'},
#      'html': {'href': 'https://github.com/tlvaldepena/skills-github-pages/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/tlvaldepena/skills-github-pages/statuses/77c68df05877388ba4fd7c66dc1887f8d8952faa'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 9,
#     'additions': 23,
#     'deletions': 39,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648998',
#   'type': 'PushEvent',
#   'actor': {'id': 172977720,
#    'login': 'lxnky',
#    'display_login': 'lxnky',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lxnky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/172977720?'},
#   'repo': {'id': 824015659,
#    'name': 'lxnky/Ethify-Updated',
#    'url': 'https://api.github.com/repos/lxnky/Ethify-Updated'},
#   'payload': {'repository_id': 824015659,
#    'push_id': 19451025465,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '48164a2b7e3c223dd368345ce3738f273e9c889d',
#    'before': 'e3e27b739c385fb272c31a3305ed8641e38f55c1',
#    'commits': [{'sha': '48164a2b7e3c223dd368345ce3738f273e9c889d',
#      'author': {'email': 'kurwabober1337@yandex.com', 'name': 'l1nky'},
#      'message': 'README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/lxnky/Ethify-Updated/commits/48164a2b7e3c223dd368345ce3738f273e9c889d'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648991',
#   'type': 'PushEvent',
#   'actor': {'id': 106276818,
#    'login': 'mirrosha26',
#    'display_login': 'mirrosha26',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mirrosha26',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106276818?'},
#   'repo': {'id': 827718316,
#    'name': 'mirrosha26/cust_mixer',
#    'url': 'https://api.github.com/repos/mirrosha26/cust_mixer'},
#   'payload': {'repository_id': 827718316,
#    'push_id': 19451025456,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '4e7222a6d074ed734cf237706c81a66c5ffa2960',
#    'before': '2f884cb8fbece61c3e0f45d6c226b6eed45ae8dc',
#    'commits': [{'sha': '4e7222a6d074ed734cf237706c81a66c5ffa2960',
#      'author': {'email': 'mirrosha26@gmail.com',
#       'name': 'Mikhail Miroshnikov'},
#      'message': 'Update All',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/mirrosha26/cust_mixer/commits/4e7222a6d074ed734cf237706c81a66c5ffa2960'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648978',
#   'type': 'PushEvent',
#   'actor': {'id': 131601531,
#    'login': 'sh-sho',
#    'display_login': 'sh-sho',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sh-sho',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/131601531?'},
#   'repo': {'id': 832045097,
#    'name': 'sh-sho/shortmovie_actions',
#    'url': 'https://api.github.com/repos/sh-sho/shortmovie_actions'},
#   'payload': {'repository_id': 832045097,
#    'push_id': 19451025453,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '317e6f59f7add6bad674d8a3d1590311131d4e12',
#    'before': '99368876fe4a6c7d49bdb2b5c0ee7320f884e188',
#    'commits': [{'sha': '317e6f59f7add6bad674d8a3d1590311131d4e12',
#      'author': {'email': 'sho.obata.c5@gmail.com', 'name': 'sh-sho'},
#      'message': 'add code',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sh-sho/shortmovie_actions/commits/317e6f59f7add6bad674d8a3d1590311131d4e12'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648966',
#   'type': 'PushEvent',
#   'actor': {'id': 158376547,
#    'login': 'leonzwrx',
#    'display_login': 'leonzwrx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/leonzwrx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/158376547?'},
#   'repo': {'id': 795778303,
#    'name': 'leonzwrx/dotfiles',
#    'url': 'https://api.github.com/repos/leonzwrx/dotfiles'},
#   'payload': {'repository_id': 795778303,
#    'push_id': 19451025441,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '28954452ca341e0455656b193ffed0bd5067d689',
#    'before': '3a9400f1350448cc644fc97ef4a75512113e36f1',
#    'commits': [{'sha': 'ae4374af6ba0f7c05320eaffefa54e30e6e4eb40',
#      'author': {'email': '158376547+leonzwrx@users.noreply.github.com',
#       'name': 'leonzwrx'},
#      'message': '07-21-24 save',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/leonzwrx/dotfiles/commits/ae4374af6ba0f7c05320eaffefa54e30e6e4eb40'},
#     {'sha': '28954452ca341e0455656b193ffed0bd5067d689',
#      'author': {'email': '158376547+leonzwrx@users.noreply.github.com',
#       'name': 'leonzwrx'},
#      'message': "Merge branch 'master' of github.com:leonzwrx/dotfiles",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/leonzwrx/dotfiles/commits/28954452ca341e0455656b193ffed0bd5067d689'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648962',
#   'type': 'PushEvent',
#   'actor': {'id': 32607012,
#    'login': 'ydddj',
#    'display_login': 'ydddj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ydddj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32607012?'},
#   'repo': {'id': 832881106,
#    'name': 'ydddj/proxy_tools',
#    'url': 'https://api.github.com/repos/ydddj/proxy_tools'},
#   'payload': {'repository_id': 832881106,
#    'push_id': 19451025443,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6428991065342a6517db9a6d0837e6c3159f9052',
#    'before': 'c2b1f0cd7bbe5f7777dd4e4b2f978b8021576d0c',
#    'commits': [{'sha': '6428991065342a6517db9a6d0837e6c3159f9052',
#      'author': {'email': '32607012+ydddj@users.noreply.github.com',
#       'name': 'ydddj'},
#      'message': 'Create plugin_update.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ydddj/proxy_tools/commits/6428991065342a6517db9a6d0837e6c3159f9052'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648952',
#   'type': 'CreateEvent',
#   'actor': {'id': 71888010,
#    'login': 'Zprit3',
#    'display_login': 'Zprit3',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Zprit3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71888010?'},
#   'repo': {'id': 832882769,
#    'name': 'Zprit3/Zprit3',
#    'url': 'https://api.github.com/repos/Zprit3/Zprit3'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648921',
#   'type': 'PushEvent',
#   'actor': {'id': 41928138,
#    'login': 'sebast759',
#    'display_login': 'sebast759',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sebast759',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41928138?'},
#   'repo': {'id': 457470784,
#    'name': 'sebast759/sebast759.github.io',
#    'url': 'https://api.github.com/repos/sebast759/sebast759.github.io'},
#   'payload': {'repository_id': 457470784,
#    'push_id': 19451025425,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e7f751f90a6485210ffad038a1b63f972deac7aa',
#    'before': 'ba971664fb6bf7b588e7667e932ad746b01f942b',
#    'commits': [{'sha': 'e7f751f90a6485210ffad038a1b63f972deac7aa',
#      'author': {'email': '41928138+sebast759@users.noreply.github.com',
#       'name': 'sebast759'},
#      'message': 'Commit_aplo',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sebast759/sebast759.github.io/commits/e7f751f90a6485210ffad038a1b63f972deac7aa'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648917',
#   'type': 'PushEvent',
#   'actor': {'id': 47427346,
#    'login': 'codemilio',
#    'display_login': 'codemilio',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codemilio',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47427346?'},
#   'repo': {'id': 823887192,
#    'name': 'codemilio/reactjs-pomodoro-timer',
#    'url': 'https://api.github.com/repos/codemilio/reactjs-pomodoro-timer'},
#   'payload': {'repository_id': 823887192,
#    'push_id': 19451025422,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'fad5fcbef853f21e3b432d56eae40e36f3447cd4',
#    'before': '570e377cdb72c4cf52f563abfae7a2f588bc9387',
#    'commits': [{'sha': 'fad5fcbef853f21e3b432d56eae40e36f3447cd4',
#      'author': {'email': 'carlosemilio.contato@gmail.com',
#       'name': 'Carlos Silva'},
#      'message': 'feat: change page title to current cycle time',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/codemilio/reactjs-pomodoro-timer/commits/fad5fcbef853f21e3b432d56eae40e36f3447cd4'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648919',
#   'type': 'PushEvent',
#   'actor': {'id': 5857923,
#    'login': 'xieweiAlex',
#    'display_login': 'xieweiAlex',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xieweiAlex',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5857923?'},
#   'repo': {'id': 91982338,
#    'name': 'xieweiAlex/English_Learning',
#    'url': 'https://api.github.com/repos/xieweiAlex/English_Learning'},
#   'payload': {'repository_id': 91982338,
#    'push_id': 19451025424,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'a664c495b591c87c9eeb66062d907d007eddcae8',
#    'before': 'a16875d34025df44b1b7232b8c847dc53556ed27',
#    'commits': [{'sha': 'a664c495b591c87c9eeb66062d907d007eddcae8',
#      'author': {'email': 'alex.xie@walmart.com', 'name': 'Alex Xie'},
#      'message': 'Changes at: 07/23/2024 06:26:07 PM',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/xieweiAlex/English_Learning/commits/a664c495b591c87c9eeb66062d907d007eddcae8'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:11Z'},
#  {'id': '40405648915',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 447371243,
#    'name': 'Senya01/Senya01',
#    'url': 'https://api.github.com/repos/Senya01/Senya01'},
#   'payload': {'repository_id': 447371243,
#    'push_id': 19451025421,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e3c5e250ca994420de6666bc819302056de37821',
#    'before': 'f9586b7db2d701ae83723c3e46f16b341b3e1aa1',
#    'commits': [{'sha': 'e3c5e250ca994420de6666bc819302056de37821',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
# ...
#       'ssh_url': 'git@github.com:cBournhonesque/jam5.git',
#       'clone_url': 'https://github.com/cBournhonesque/jam5.git',
#       'svn_url': 'https://github.com/cBournhonesque/jam5',
#       'homepage': None,
#       'size': 14454,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Rust',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'cBournhonesque:main',
#      'ref': 'main',
#      'sha': '4589ca2b2b72b94de95b0bca8f2d09ed2260f41a',
#      'user': {'login': 'cBournhonesque',
#       'id': 8112632,
#       'node_id': 'MDQ6VXNlcjgxMTI2MzI=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8112632?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cBournhonesque',
#       'html_url': 'https://github.com/cBournhonesque',
#       'followers_url': 'https://api.github.com/users/cBournhonesque/followers',
#       'following_url': 'https://api.github.com/users/cBournhonesque/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cBournhonesque/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cBournhonesque/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cBournhonesque/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cBournhonesque/orgs',
#       'repos_url': 'https://api.github.com/users/cBournhonesque/repos',
#       'events_url': 'https://api.github.com/users/cBournhonesque/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cBournhonesque/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 831458688,
#       'node_id': 'R_kgDOMY8NgA',
#       'name': 'jam5',
#       'full_name': 'cBournhonesque/jam5',
#       'private': False,
#       'owner': {'login': 'cBournhonesque',
#        'id': 8112632,
#        'node_id': 'MDQ6VXNlcjgxMTI2MzI=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/8112632?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cBournhonesque',
#        'html_url': 'https://github.com/cBournhonesque',
#        'followers_url': 'https://api.github.com/users/cBournhonesque/followers',
#        'following_url': 'https://api.github.com/users/cBournhonesque/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cBournhonesque/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cBournhonesque/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cBournhonesque/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cBournhonesque/orgs',
#        'repos_url': 'https://api.github.com/users/cBournhonesque/repos',
#        'events_url': 'https://api.github.com/users/cBournhonesque/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cBournhonesque/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/cBournhonesque/jam5',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/cBournhonesque/jam5',
#       'forks_url': 'https://api.github.com/repos/cBournhonesque/jam5/forks',
#       'keys_url': 'https://api.github.com/repos/cBournhonesque/jam5/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cBournhonesque/jam5/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cBournhonesque/jam5/teams',
#       'hooks_url': 'https://api.github.com/repos/cBournhonesque/jam5/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cBournhonesque/jam5/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cBournhonesque/jam5/events',
#       'assignees_url': 'https://api.github.com/repos/cBournhonesque/jam5/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cBournhonesque/jam5/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cBournhonesque/jam5/tags',
#       'blobs_url': 'https://api.github.com/repos/cBournhonesque/jam5/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cBournhonesque/jam5/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cBournhonesque/jam5/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cBournhonesque/jam5/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cBournhonesque/jam5/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cBournhonesque/jam5/languages',
#       'stargazers_url': 'https://api.github.com/repos/cBournhonesque/jam5/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cBournhonesque/jam5/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cBournhonesque/jam5/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cBournhonesque/jam5/subscription',
#       'commits_url': 'https://api.github.com/repos/cBournhonesque/jam5/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cBournhonesque/jam5/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cBournhonesque/jam5/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cBournhonesque/jam5/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cBournhonesque/jam5/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cBournhonesque/jam5/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cBournhonesque/jam5/merges',
#       'archive_url': 'https://api.github.com/repos/cBournhonesque/jam5/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cBournhonesque/jam5/downloads',
#       'issues_url': 'https://api.github.com/repos/cBournhonesque/jam5/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cBournhonesque/jam5/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cBournhonesque/jam5/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cBournhonesque/jam5/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cBournhonesque/jam5/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cBournhonesque/jam5/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cBournhonesque/jam5/deployments',
#       'created_at': '2024-07-20T15:57:22Z',
#       'updated_at': '2024-07-23T21:23:46Z',
#       'pushed_at': '2024-07-23T23:26:04Z',
#       'git_url': 'git://github.com/cBournhonesque/jam5.git',
#       'ssh_url': 'git@github.com:cBournhonesque/jam5.git',
#       'clone_url': 'https://github.com/cBournhonesque/jam5.git',
#       'svn_url': 'https://github.com/cBournhonesque/jam5',
#       'homepage': None,
#       'size': 14454,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Rust',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/cBournhonesque/jam5/pulls/23'},
#      'html': {'href': 'https://github.com/cBournhonesque/jam5/pull/23'},
#      'issue': {'href': 'https://api.github.com/repos/cBournhonesque/jam5/issues/23'},
#      'comments': {'href': 'https://api.github.com/repos/cBournhonesque/jam5/issues/23/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/cBournhonesque/jam5/pulls/23/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/cBournhonesque/jam5/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/cBournhonesque/jam5/pulls/23/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/cBournhonesque/jam5/statuses/d233cf231e482200ca0d5f1b95115418aa21fb84'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'cBournhonesque',
#      'id': 8112632,
#      'node_id': 'MDQ6VXNlcjgxMTI2MzI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/8112632?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/cBournhonesque',
#      'html_url': 'https://github.com/cBournhonesque',
#      'followers_url': 'https://api.github.com/users/cBournhonesque/followers',
#      'following_url': 'https://api.github.com/users/cBournhonesque/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/cBournhonesque/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/cBournhonesque/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/cBournhonesque/subscriptions',
#      'organizations_url': 'https://api.github.com/users/cBournhonesque/orgs',
#      'repos_url': 'https://api.github.com/users/cBournhonesque/repos',
#      'events_url': 'https://api.github.com/users/cBournhonesque/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/cBournhonesque/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 50,
#     'deletions': 8,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2024-07-23T23:26:10Z'},
#  {'id': '40405648853',
#   'type': 'PushEvent',
#   'actor': {'id': 125873073,
#    'login': 'Queenbaloyi',
#    'display_login': 'Queenbaloyi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Queenbaloyi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/125873073?'},
#   'repo': {'id': 832831011,
#    'name': 'Queenbaloyi/Bridgeway-connecting-students-and-companies-',
#    'url': 'https://api.github.com/repos/Queenbaloyi/Bridgeway-connecting-students-and-companies-'},
#   'payload': {'repository_id': 832831011,
#    'push_id': 19451025380,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0e9b772497d86ae694b52073651f98e7ab852c2c',
#    'before': 'c7d56dd1ad27a11f266adea6678f05c3766e552c',
#    'commits': [{'sha': '0e9b772497d86ae694b52073651f98e7ab852c2c',
#      'author': {'email': '125873073+Queenbaloyi@users.noreply.github.com',
#       'name': 'Queenbaloyi'},
#      'message': 'Update style.scss\n\nUpdate: css file added',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Queenbaloyi/Bridgeway-connecting-students-and-companies-/commits/0e9b772497d86ae694b52073651f98e7ab852c2c'}]},
#   'public': True,
#   'created_at': '2024-07-23T23:26:10Z'},
#  {'id': '40405648840',
#   'type': 'IssuesEvent',
#   'actor': {'id': 9399151,
#    'login': 'tsunamit',
#    'display_login': 'tsunamit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tsunamit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9399151?'},
#   'repo': {'id': 798884259,
#    'name': 'mlcommons/modeltune',
#    'url': 'https://api.github.com/repos/mlcommons/modeltune'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/mlcommons/modeltune/issues/23',
#     'repository_url': 'https://api.github.com/repos/mlcommons/modeltune',
#     'labels_url': 'https://api.github.com/repos/mlcommons/modeltune/issues/23/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/mlcommons/modeltune/issues/23/comments',
#     'events_url': 'https://api.github.com/repos/mlcommons/modeltune/issues/23/events',
#     'html_url': 'https://github.com/mlcommons/modeltune/issues/23',
#     'id': 2402323461,
#     'node_id': 'I_kwDOL54Bo86PMIwF',
#     'number': 23,
#     'title': 'Automate pseudo ground truth labels using teacher models',
#     'user': {'login': 'tsunamit',
#      'id': 9399151,
#      'node_id': 'MDQ6VXNlcjkzOTkxNTE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9399151?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tsunamit',
#      'html_url': 'https://github.com/tsunamit',
#      'followers_url': 'https://api.github.com/users/tsunamit/followers',
#      'following_url': 'https://api.github.com/users/tsunamit/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tsunamit/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tsunamit/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tsunamit/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tsunamit/orgs',
#      'repos_url': 'https://api.github.com/users/tsunamit/repos',
#      'events_url': 'https://api.github.com/users/tsunamit/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tsunamit/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 7242266968,
#       'node_id': 'LA_kwDOL54Bo88AAAABr6w5WA',
#       'url': 'https://api.github.com/repos/mlcommons/modeltune/labels/[COMPONENT]%20Data%20Engine',
#       'name': '[COMPONENT] Data Engine',
#       'color': 'fbca04',
#       'default': False,
#       'description': 'Processing new data sources, preparing data for training'},
#      {'id': 7242315944,
#       'node_id': 'LA_kwDOL54Bo88AAAABr6z4qA',
#       'url': 'https://api.github.com/repos/mlcommons/modeltune/labels/Data%20Engine%20/%20Auto%20Safety%20Labeling',
#       'name': 'Data Engine / Auto Safety Labeling',
#       'color': 'edf0a1',
#       'default': False,
#       'description': ''}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2024-07-11T06:03:29Z',
#     'updated_at': '2024-07-23T23:26:09Z',
#     'closed_at': '2024-07-23T23:26:09Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': '- coordinate with this task: https://github.com/mlcommons/modeltune/issues/21\n- (ideally) Migrate the logic from this PR (https://github.com/mlcommons/modeltune/pull/2) to modelgauge where we can leverage an ensemble of annotators to generate the pseudo ground truth labels\n- input: rows of prompt + SUT response\n- result: pseudo ground truth label (computed by the majority vote of several safety models in the ensemble)\n',
#     'reactions': {'url': 'https://api.github.com/repos/mlcommons/modeltune/issues/23/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/mlcommons/modeltune/issues/23/timeline',
#     'performed_via_github_app': None,
#     'state_reason': 'completed'}},
#   'public': True,
#   'created_at': '2024-07-23T23:26:10Z',
#   'org': {'id': 67760141,
#    'login': 'mlcommons',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/mlcommons',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67760141?'}}]

# %%
usuarioGithub = requests.get('https://api.github.com/users/beabritoliveira')

# %%
usuarioGithub.json()['name']
# Out:
# 'Beatriz'

# %%
usuarioGithub.json()['login']
# Out:
# 'beabritoliveira'

# %%
usuarioGithub.json()['public_repos']
# Out:
# 16

# %%
usuarioGithub.json()['created_at']
# Out:
# '2022-04-05T12:28:27Z'

# %% [markdown]
# ### Pipeline ETL
# - Extração (Extract) => coleta de dados de uma ou mais fonte, nenhum tratamento é feito
# - Transformação(Transform) => processo de limpeza dos dados, padronização e outros tratamentos (demorada e trabalhosa)
# - Carregamento(Load) => dados são movidos para o destino final, dw ou sistema de armazenamento

# %%
# Extração de dados das linguagens utilizadas pelas grandes empresas

# especificando a versão da API do github que será usada para fazer a extração
headers = {'X-GitHub-Api-Version': '2022-11-28'}
api_base_url = 'https://api.github.com'
owner = 'amzn' #conteúdo relativo ao nome do usuario que se vai extrair os dados dos repositorios (nesse caso é a amazon)
url = f'{api_base_url}/users/{owner}/repos'

# %%
response = requests.get(url , headers=headers)
response.status_code
# Out:
# 200

# %% [markdown]
# Parâmetros do metodo GET:
# - params: um dicionário ou lista de tuplas contendo os parâmetros de consulta a serem incluídos na URL. Por exemplo, para fazer uma requisição GET para a API do GitHub e obter os repositórios de forma ordenada, pode-se passar o argumento params={”sort”: “name”} e ter os repositórios em ordem alfabética. Isso resultaria em uma URL como esta:

# %%
#quantidade de repositorios já que cada elemento nesse json é um respositorio
len(response.json())

#utilizando os processos de autenticação e paginação para conseguir pegar todos os repositórios e não só o que estão na primeira página
acess_token = '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'
headers = {'Authorization':'Bearer ' + acess_token , 
           'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
owner = 'amzn' #conteúdo relativo ao nome do usuario que se vai extrair os dados dos repositorios (nesse caso é a amazon)
url = f'{api_base_url}/users/{owner}/repos'

# %%
# defini uma lista vazia para guardar cada uma das páginas extraidas com seus respectivos repositórios
#  na nossa lista repos_list corresponde a uma página, e cada dicionário corresponde a um repositório.
repos_list = []
# laço for para percorrer as páginas
for page_num in range(1,7):
    try:
        # onde se é possível extrair os dados de cada página => page={page_num}
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page , headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
len(repos_list[5])
# Out:
# 4

# %% [markdown]
# Pegando o nome dos repositórios e as linguagens usadas nelas

# %%
# repos_list[num_pagina][num_repositorio]['name']
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-template'

# %%
repos_name = []

for pagina in range (len(repos_list)): # ou for page in repos_list
    for repos in range (len(repos_list[pagina])): # for repo in page
            repos_name.append(repos_list[pagina][repos]['name']) # repos_name.append(repo['name'])

# %%
repos_name[:10]
len(repos_name)
# Out:
# 154

# %%
type(repos_list)
type(repos_list[0][0])
# Out:
# dict

# %% [markdown]
# Selecionando a linguagem de cada repositorio

# %%
repos_list[2][15]['language']
# Out:
# 'Python'

# %%
repos_language = []

for page in repos_list:
    for repo in page:
            repos_language.append(repo['language'])

# %%
len(repos_language)
# Out:
# 154

# %%
repos_language[:10]
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS']

# %% [markdown]
# ### Criando um DataFrame

# %%
import numpy as np

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
#criando colunas
dados_amz['repositorie_name'] = repos_name
dados_amz['language'] = repos_language

# %%
# salvando o dataframe em um arquivo
dados_amz.to_csv('linguas_rep_Amazon.csv' , sep=';', index=False)

# %%
dados_amz
# Out:
#                 repositorie_name          language
# 0                        .github              None
# 1        ads-advanced-tools-docs  Jupyter Notebook
# 2    ads-pao-amznjs-gtm-template            Smarty
# 3                     alexa-coho        JavaScript
# 4            alexa-skills-kit-js              None
# ..                           ...               ...
# 149             zeek-plugin-enip              Zeek
# 150         zeek-plugin-profinet              Zeek
# 151           zeek-plugin-s7comm              Zeek
# 152              zeek-plugin-tds              Zeek
# 153               zero-shot-rlhr            Python
#
# [154 rows x 2 columns]

# %%
pd.read_csv('/home/bia/projeto_Requests/linguas_rep_Amazon.csv')
# Out:
#                     repositorie_name;language
# 0                                    .github;
# 1    ads-advanced-tools-docs;Jupyter Notebook
# 2          ads-pao-amznjs-gtm-template;Smarty
# 3                       alexa-coho;JavaScript
# 4                        alexa-skills-kit-js;
# ..                                        ...
# 149                     zeek-plugin-enip;Zeek
# 150                 zeek-plugin-profinet;Zeek
# 151                   zeek-plugin-s7comm;Zeek
# 152                      zeek-plugin-tds;Zeek
# 153                     zero-shot-rlhr;Python
#
# [154 rows x 1 columns]

# %% [markdown]
# ### Criando um repositorio no github

# %%
url = f'{api_base_url}/user/repos'

# %%
url
# Out:
# 'https://api.github.com/user/repos'

# %%
# fazendo uma requisição do tipo post  => criaçaõ do repositório na página pessoal
data = {
    'name' : 'linguages_utilizadas',
    'description' : 'Repositorio curso Python e APIs: conhecendo biblioteca Requests da Alura em que busca as linguagens de programação de todos os repositórios até o momento do github da Amazon',
    'private' : True
}

response = requests.post(url , json=data , headers=headers)
response.status_code
# Out:
# 404

# %%
# subindo o arquivo csv para o repositório do github
# 1°) transforma em Base64 (transforma arquivos em uma sequencia de caracteres) o csv 
import base64

# ler o arquivo csv em formato binário
with open('/home/bia/projeto_Requests/linguas_rep_Amazon.csv', 'rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)

#upload do arquivo com o PUT
username = 'beabritoliveira'
repo = 'linguages_utilizadas'
path = 'amazon.csv' #nome do arquivo fique salvo no repositório
url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'

# definir o dicionario para fazer a atualização do arquivo
data = {
    'message' : 'Adicionando um novo arquivo', # mensagem de commit 
    'content' : encoded_content.decode('utf-8') # passa o arquivo codificado em base64
}

response = requests.put(url, json=data , headers=headers)
response.status_code
# Out:
# 201

# %% [markdown]
# ### Utilizando Orientação a Objeto
